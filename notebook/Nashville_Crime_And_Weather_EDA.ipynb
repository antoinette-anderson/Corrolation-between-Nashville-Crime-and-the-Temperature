# %%
import pandas as pd
import matplotlib as mp
import seaborn as sns
import numpy as np

# %%
nashvillecrime_df=pd.read_csv("..\data\Metro_Nashville_Police_Department_Incidents_20240215.csv")

# %%
nashvillecrime_df.head()
# Out:
#       Primary Key  Incident Number Report Type Report Type Description  \
# 0  20240103838_23      20240103838           D              DISPATCHED
# 1  20240103838_12      20240103838           D              DISPATCHED
# 2  20240103838_11      20240103838           D              DISPATCHED
# 3  20240103523_11      20240103523           T                     NaN
# 4  20240102993_11      20240102993           D              DISPATCHED
#
#   Incident Status Code Incident Status Description Investigation Status  \
# 0                    O                        OPEN                 Open
# 1                    O                        OPEN                 Open
# 2                    O                        OPEN                 Open
# 3                    O                        OPEN                 Open
# 4                    O                        OPEN                 Open
#
#         Incident Occurred       Incident Reported     Incident Location  ...  \
# ...

# %%
nashvillecrime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122764 entries, 0 to 122763
# Data columns (total 35 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Primary Key                      122764 non-null  object
#  1   Incident Number                  122764 non-null  int64
#  2   Report Type                      122734 non-null  object
#  3   Report Type Description          112165 non-null  object
#  4   Incident Status Code             122764 non-null  object
#  5   Incident Status Description      122753 non-null  object
#  6   Investigation Status             122764 non-null  object
#  7   Incident Occurred                122764 non-null  object
#  8   Incident Reported                122764 non-null  object
#  9   Incident Location                120353 non-null  object
#  10  Latitude                         118035 non-null  float64
# ...

# %%
nashvillecrime_df['Offense Description']
# Out:
# 0         WEAPON OFFENSE, CRIMINAL ATTEMPT
# 1           INTENTIONAL AGGRAVATED ASSAULT
# 2           INTENTIONAL AGGRAVATED ASSAULT
# 3                   CRIMINAL IMPERSONATION
# 4                    DAMAGE PROP - PRIVATE
#                         ...
# 122759             BURGLARY- MOTOR VEHICLE
# 122760                       LOST PROPERTY
# 122761                   CRIMINAL TRESPASS
# 122762                      FOUND PROPERTY
# 122763                         SHOPLIFTING
# Name: Offense Description, Length: 122764, dtype: object

# %%
nashvillecrime_df['Offense Description'].value_counts()
# Out:
# Offense Description
# POLICE INQUIRY                                                  22625
# BURGLARY- MOTOR VEHICLE                                          9461
# SIMPLE ASSLT                                                     6355
# VEHICLE THEFT                                                    5292
# FOUND PROPERTY                                                   4885
#                                                                 ...
# Drug Free NonSch.Zone-Cont.Sub.-Meth 300 gr or >                    1
# ASSAULT, AGG - DEATH -INT/KN- VEH/MINOR VIC-ACT IN CONCERT          1
# BRIBE - OFFERING                                                    1
# Counterfeit Log - Manuf. Items - $60,000 or > but < $250,000        1
# DOG GUIDE VIOLATION                                                 1
# Name: count, Length: 398, dtype: int64

# %%
nashvillecrime_df['ZIP Code'].value_counts()
# Out:
# ZIP Code
# 37013.0    6630
# 37211.0    5960
# 37207.0    5868
# 37115.0    4816
# 37203.0    4171
#            ...
# 37179.0       1
# 37028.0       1
# 60123.0       1
# 37067.0       1
# 37330.0       1
# Name: count, Length: 62, dtype: int64

# %%
nashvillecrime_df.describe()
# Out:
#        Incident Number       Latitude      Longitude      ZIP Code  \
# count     1.227640e+05  118035.000000  118035.000000  61926.000000
# mean      2.023043e+10      36.149914     -86.739455  37172.506039
# std       8.239863e+05       0.364506       0.365379    378.408944
# min       2.013014e+10     -86.976000     -87.040000      0.000000
# 25%       2.023021e+10      36.096000     -86.787000  37138.000000
# 50%       2.023039e+10      36.154000     -86.750000  37207.000000
# 75%       2.023057e+10      36.190000     -86.690000  37211.000000
# max       2.024010e+10      36.399000      36.045000  91107.000000
#
#                RPA        Zone  Location Code  Offense Number  Victim Number  \
# count    85.000000   85.000000  122758.000000   122747.000000  122764.000000
# mean   5027.211765  480.600000      27.941910        1.129494       1.246742
# std    2364.996401  138.462579      24.828412        0.411617       1.061975
# ...

# %%
nashvillecrime_df['Victim Gender'].value_counts()
# Out:
# Victim Gender
# F    49302
# M    42314
# U     3991
# Name: count, dtype: int64

# %%
nashvillecrime_df['Victim Race'].value_counts()
# Out:
# Victim Race
# W    50630
# B    34756
# U     8733
# A     1231
# I      161
# P       82
# H        7
# O        4
# T        2
# Name: count, dtype: int64

# %%
nashvillecrime_df['Incident Occurred'].value_counts()
# Out:
# Incident Occurred
# 01/01/2023 12:00:00 AM    65
# 09/05/2023 07:00:00 PM    43
# 05/01/2023 12:00:00 PM    42
# 03/12/2023 03:15:00 PM    40
# 08/01/2023 08:00:00 AM    40
#                           ..
# 07/30/2023 04:14:00 PM     1
# 07/30/2023 04:21:00 PM     1
# 07/30/2023 12:50:00 PM     1
# 07/30/2023 04:40:00 PM     1
# 02/27/2023 12:15:00 PM     1
# Name: count, Length: 59918, dtype: int64

# %%
import requests

# %%
URL= 'https://www.extremeweatherwatch.com/cities/nashville/year-2023'

response=requests.get(URL)

# %%
type(response)
# Out:
# requests.models.Response

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang=\'en\'>\n<head>\n  <meta name=\'description\' content="">\n  <meta http-equiv=\'Content-Type\' content=\'text/html; charset=UTF-8\'>\n  <meta name=\'viewport\' content=\'width=device-width, initial-scale=1\'>\n  <meta name=\'apple-mobile-web-app-capable\' content=\'yes\' />\n  <link rel=\'icon\' type=\'image/png\' href=\'https://extremeweatherwatch.b-cdn.net/favicon-96x96.png\' sizes=\'96x96\' />\n  <link rel=\'icon\' type=\'image/png\' href=\'https://extremeweatherwatch.b-cdn.net/favicon-32x32.png\' sizes=\'32x32\' />\n  <link rel=\'icon\' type=\'image/png\' href=\'https://extremeweatherwatch.b-cdn.net/favicon-16x16.png\' sizes=\'16x16\' />\n  <script type=\'text/javascript\' async src=\'https://extremeweatherwatch.b-cdn.net/resources/asc.extremeweatherwatch.js?1705957277\'></script>\n  <link rel=\'stylesheet\' href=\'//cdnjs.cloudflare.com/ajax/libs/font-awesome/5.8.2/css/all.css\'>\n<link rel=\'stylesheet\' href=\'//cdnjs.cloudflare.com/ajax/libs/twitt
# ...

# %%
from bs4 import BeautifulSoup as BS

# %%
soup = BS(response.text)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="" name="description"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <link href="https://extremeweatherwatch.b-cdn.net/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="https://extremeweatherwatch.b-cdn.net/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://extremeweatherwatch.b-cdn.net/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <script async="" src="https://extremeweatherwatch.b-cdn.net/resources/asc.extremeweatherwatch.js?1705957277" type="text/javascript">
#   </script>
#   <link href="//cdnjs.cloudflare.com/ajax/libs/font-awesome/5.8.2/css/all.css" rel="stylesheet"/>
# ...

# %%
soup.find('title')
# Out:
# <title>Nashville Weather in 2023</title>

# %%
soup.findAll('table')
# Out:
# [<table class="bordered-table mt-4">
#  <tr>
#  <th colspan="3">2023 Nashville Weather Extremes</th>
#  </tr>
#  <tr>
#  <td><a href="#highest_temperatures">Highest temperature</a></td>
#  <td class="text-right">100 °F</td>
#  <td class="text-right">August 25</td>
#  </tr>
#  <tr>
#  <td><a href="#lowest_temperatures">Lowest temperature</a></td>
#  <td class="text-right">19 °F</td>
#  <td class="text-right">February 4</td>
#  </tr>
#  <tr>
#  <td>Highest daily low</td>
#  <td class="text-right">77 °F</td>
#  <td class="text-right">August 23</td>
#  </tr>
#  <tr>
#  <td>Lowest daily high</td>
#  <td class="text-right">33 °F</td>
#  <td class="text-right">February 1</td>
#  </tr>
#  <tr>
#  <td>Most daily precipitation</td>
#  <td class="text-right">2.2 inches</td>
#  <td class="text-right">May 7</td>
#  </tr>
#  <tr>
#  <td>Most daily snow</td>
#  <td class="text-right">none</td>
#  <td class="text-right">-</td>
#  </tr>
#  <tr>
#  <td>Total annual precipitation</td>
# ...

# %%
import pandas as pd

# %%
soup.find('table', attrs={'class' : 'bordered-table daily-table'})
# Out:
# <table class="bordered-table daily-table">
# <tr>
# <th>Day</th>
# <th>High <span class="fs-13">(°F)</span></th>
# <th>Low <span class="fs-13">(°F)</span></th>
# <th>Precip. <span class="fs-13">(inches)</span></th>
# </tr>
# <tr>
# <td><div class="width-130"><a href="/cities/nashville/day/january-1">January 1</a></div></td>
# <td class="text-right temp70">70</td>
# <td class="text-right temp40">45</td>
# <td class="text-right">0.00</td>
# </tr>
# <tr>
# <td><div class="width-130"><a href="/cities/nashville/day/january-2">January 2</a></div></td>
# <td class="text-right temp70">75</td>
# <td class="text-right temp50">53</td>
# <td class="text-right rainsnow1">0.04</td>
# </tr>
# <tr>
# <td><div class="width-130"><a href="/cities/nashville/day/january-3">January 3</a></div></td>
# <td class="text-right temp70">71</td>
# <td class="text-right temp50">58</td>
# <td class="text-right rainsnow1">1.53</td>
# </tr>
# <tr>
# ...

# %%
pd.read_html(str(soup.find('table', attrs={'class' : 'bordered-table daily-table'})))[0]
# Out:
#            Day  High (°F)  Low (°F)  Precip. (inches)
# 0    January 1         70        45              0.00
# 1    January 2         75        53              0.04
# 2    January 3         71        58              1.53
# 3    January 4         65        45              0.07
# 4    January 5         56        36              0.00
# 5    January 6         55        31              0.00
# 6    January 7         49        40              0.11
# 7    January 8         51        39              0.00
# 8    January 9         53        34              0.00
# 9   January 10         62        30              0.00
# 10  January 11         66        48              0.00
# 11  January 12         69        40              0.31
# 12  January 13         40        33              0.01
# 13  January 14         40        29              0.00
# 14  January 15         54        26              0.00
# 15  January 16         60        36              0.12
# ...
